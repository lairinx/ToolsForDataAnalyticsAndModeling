# %% [markdown]
# # Data Indexing and Selection Examples
#
# 2020-09-28 - Jeff Smith

# %%
# Getting things ready
import numpy as np
import pandas as pd
from datetime import datetime

def show(data, show_data = 0):
    print ("   Type: {:}".format(type(data)))
    print ("  Index: {:}".format(data.index))
    print ("  Shape: {:}".format(data.shape))
    print ("Columns: {:}".format(data.columns))
    for col in data.columns:
        print ("    {:} ({:})".format(col,data[col].dtype))
    if show_data == 1:
        print(data.head())
    elif show_data == 2:
        print(data.values)
        
print("Pandas version: {:}".format(pd.__version__))

filepath = "../data/"
# Out:
# Pandas version: 1.0.5

# %% [markdown]
# ## US Economic Data dataset
# ## Default read_csv()

# %%
# Start with the US Economic Data dataset.
df1 = pd.read_csv(filepath + '10_us_economic_data.csv')
show(df1,1)
# Out:
#    Type: <class 'pandas.core.frame.DataFrame'>
#   Index: RangeIndex(start=0, stop=128, step=1)
#   Shape: (128, 4)
# Columns: Index(['Month', 'UnemploymentRate', 'JobsAdded', 'GDP'], dtype='object')
#     Month (object)
#     UnemploymentRate (float64)
#     JobsAdded (float64)
#     GDP (float64)
#     Month  UnemploymentRate  JobsAdded       GDP
# 0  1/2008               5.0        8.0  14651.04
# 1  2/2008               4.9      -81.0       NaN
# 2  3/2008               5.1      -55.0       NaN
# 3  4/2008               5.0     -229.0  14805.61
# 4  5/2008               5.4     -184.0       NaN

# %%
# Extracting a single column (as a Series)
# Month - Either syntax works since the column name is alpha and is not a keyword.
df1.Month
#df1["Month"]
# Out:
# 0      1/2008
# 1      2/2008
# 2      3/2008
# 3      4/2008
# 4      5/2008
#         ...
# 123    4/2018
# 124    5/2018
# 125    6/2018
# 126    7/2018
# 127    8/2018
# Name: Month, Length: 128, dtype: object

# %%
# Extracting multiple Columns
df1[['Month', 'UnemploymentRate']]
# note the double brackets
# Out:
#       Month  UnemploymentRate
# 0    1/2008               5.0
# 1    2/2008               4.9
# 2    3/2008               5.1
# 3    4/2008               5.0
# 4    5/2008               5.4
# ..      ...               ...
# 123  4/2018               3.9
# 124  5/2018               3.8
# 125  6/2018               4.0
# 126  7/2018               3.9
# 127  8/2018               3.9
#
# [128 rows x 2 columns]

# %%
# What about the first 12 entries (the first year of data)?
df1.loc[0:11]
# why does the row for index 11 show up?  For normal Python slices, it would not (why not?)
# Try iloc rather than loc.
# Out:
#       Month  UnemploymentRate  JobsAdded       GDP
# 0    1/2008               5.0        8.0  14651.04
# 1    2/2008               4.9      -81.0       NaN
# 2    3/2008               5.1      -55.0       NaN
# 3    4/2008               5.0     -229.0  14805.61
# 4    5/2008               5.4     -184.0       NaN
# 5    6/2008               5.6     -154.0       NaN
# 6    7/2008               5.8     -213.0  14835.19
# 7    8/2008               6.1     -277.0       NaN
# 8    9/2008               6.1     -443.0       NaN
# 9   10/2008               6.5     -475.0  14559.54
# 10  11/2008               6.8     -759.0       NaN
# 11  12/2008               7.3     -707.0       NaN

# %%
# What month had the highest unemployment rate?
rate = df1.UnemploymentRate.max()
df1.loc[df1.UnemploymentRate == rate]
# Out:
#       Month  UnemploymentRate  JobsAdded       GDP
# 21  10/2009              10.0     -209.0  14628.02

# %%
# or all at once
df1.loc[df1.UnemploymentRate == df1.UnemploymentRate.max()]
# Out:
#       Month  UnemploymentRate  JobsAdded       GDP
# 21  10/2009              10.0     -209.0  14628.02

# %%
# Can also apply the max function to the DataFrame
df1.max()
# Also try min(), sum(), std() and others ..
# https://pandas.pydata.org/pandas-docs/stable/reference/frame.html
# Out:
# Month                9/2017
# UnemploymentRate         10
# JobsAdded               522
# GDP                 20621.1
# dtype: object

# %%
# What months had the unemployment rate greater than or equal to 9.5
df1[df1.UnemploymentRate >= 9.5]
# Here the index expression is a mask -- see the next cell
# Out:
#       Month  UnemploymentRate  JobsAdded       GDP
# 17   6/2009               9.5     -469.0       NaN
# 18   7/2009               9.5     -342.0  14420.31
# 19   8/2009               9.6     -196.0       NaN
# 20   9/2009               9.8     -229.0       NaN
# 21  10/2009              10.0     -209.0  14628.02
# 22  11/2009               9.9       12.0       NaN
# 23  12/2009               9.9     -277.0       NaN
# 24   1/2010               9.8       18.0  14721.35
# 25   2/2010               9.8      -73.0       NaN
# 26   3/2010               9.9      193.0       NaN
# 27   4/2010               9.9      221.0  14926.10
# 28   5/2010               9.6      522.0       NaN
# 31   8/2010               9.5      -16.0       NaN
# 32   9/2010               9.5      -63.0       NaN
# 34  11/2010               9.8      129.0       NaN

# %%
# the mask
df1.UnemploymentRate >= 9.5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# Name: UnemploymentRate, Length: 128, dtype: bool

# %%
# What about the Unemployment Rate and Jobs Added numbers for 
# the year 2010?
df1[['Month', 'UnemploymentRate','JobsAdded']].loc[24:35]
# Out:
#       Month  UnemploymentRate  JobsAdded
# 24   1/2010               9.8       18.0
# 25   2/2010               9.8      -73.0
# 26   3/2010               9.9      193.0
# 27   4/2010               9.9      221.0
# 28   5/2010               9.6      522.0
# 29   6/2010               9.4     -140.0
# 30   7/2010               9.4      -78.0
# 31   8/2010               9.5      -16.0
# 32   9/2010               9.5      -63.0
# 33  10/2010               9.4      267.0
# 34  11/2010               9.8      129.0
# 35  12/2010               9.3       73.0

# %%
# or
df1.iloc[24:36, :3]
# Out:
#       Month  UnemploymentRate  JobsAdded
# 24   1/2010               9.8       18.0
# 25   2/2010               9.8      -73.0
# 26   3/2010               9.9      193.0
# 27   4/2010               9.9      221.0
# 28   5/2010               9.6      522.0
# 29   6/2010               9.4     -140.0
# 30   7/2010               9.4      -78.0
# 31   8/2010               9.5      -16.0
# 32   9/2010               9.5      -63.0
# 33  10/2010               9.4      267.0
# 34  11/2010               9.8      129.0
# 35  12/2010               9.3       73.0

# %%
# or
df1.loc[24:35,['Month', 'UnemploymentRate','JobsAdded']]
# Out:
#       Month  UnemploymentRate  JobsAdded
# 24   1/2010               9.8       18.0
# 25   2/2010               9.8      -73.0
# 26   3/2010               9.9      193.0
# 27   4/2010               9.9      221.0
# 28   5/2010               9.6      522.0
# 29   6/2010               9.4     -140.0
# 30   7/2010               9.4      -78.0
# 31   8/2010               9.5      -16.0
# 32   9/2010               9.5      -63.0
# 33  10/2010               9.4      267.0
# 34  11/2010               9.8      129.0
# 35  12/2010               9.3       73.0

# %%
# What aobut the JobsAdded for the 12 month period after the month 
# with the maximum unemployment rate
# From the previous query, I knwo that max unemployment occured at loc 21
df1[['Month', 'JobsAdded', 'UnemploymentRate']].loc[22:33]
# Out:
#       Month  JobsAdded  UnemploymentRate
# 22  11/2009       12.0               9.9
# 23  12/2009     -277.0               9.9
# 24   1/2010       18.0               9.8
# 25   2/2010      -73.0               9.8
# 26   3/2010      193.0               9.9
# 27   4/2010      221.0               9.9
# 28   5/2010      522.0               9.6
# 29   6/2010     -140.0               9.4
# 30   7/2010      -78.0               9.4
# 31   8/2010      -16.0               9.5
# 32   9/2010      -63.0               9.5
# 33  10/2010      267.0               9.4

# %%
# or -- by using the argmax ("argument for entry with maximum value") function:
df1[['Month', 'JobsAdded', 'UnemploymentRate']].loc[df1.UnemploymentRate.argmax()+1:df1.UnemploymentRate.argmax()+12]
# Out:
#       Month  JobsAdded  UnemploymentRate
# 22  11/2009       12.0               9.9
# 23  12/2009     -277.0               9.9
# 24   1/2010       18.0               9.8
# 25   2/2010      -73.0               9.8
# 26   3/2010      193.0               9.9
# 27   4/2010      221.0               9.9
# 28   5/2010      522.0               9.6
# 29   6/2010     -140.0               9.4
# 30   7/2010      -78.0               9.4
# 31   8/2010      -16.0               9.5
# 32   9/2010      -63.0               9.5
# 33  10/2010      267.0               9.4

# %% [markdown]
# ## Enhanced call to read_csv()
#
# In the default version of the DataFrame, the date was read as string objects.  This makes date arithmetic clunky.  Let's try reading them in as datetime objects and setting the month to be the DataFrame index.

# %%
# Here, if I want to use the Month as the index AND specify that Pandas
# parse the dates for the index:
df2 = pd.read_csv(filepath + '10_us_economic_data.csv', parse_dates = ['Month'], index_col=0)
show(df2,1)
# Out:
#    Type: <class 'pandas.core.frame.DataFrame'>
#   Index: DatetimeIndex(['2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01',
#                '2008-05-01', '2008-06-01', '2008-07-01', '2008-08-01',
#                '2008-09-01', '2008-10-01',
#                ...
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01',
#                '2018-07-01', '2018-08-01'],
#               dtype='datetime64[ns]', name='Month', length=128, freq=None)
#   Shape: (128, 3)
# Columns: Index(['UnemploymentRate', 'JobsAdded', 'GDP'], dtype='object')
#     UnemploymentRate (float64)
#     JobsAdded (float64)
#     GDP (float64)
#             UnemploymentRate  JobsAdded       GDP
# Month
# 2008-01-01               5.0        8.0  14651.04
# 2008-02-01               4.9      -81.0       NaN
# 2008-03-01               5.1      -55.0       NaN
# 2008-04-01               5.0     -229.0  14805.61
# 2008-05-01               5.4     -184.0       NaN

# %%
# Note that we can alway using the native Python (implicit) referencing.
df2.iloc[0:12]
# Out:
#             UnemploymentRate  JobsAdded       GDP
# Month
# 2008-01-01               5.0        8.0  14651.04
# 2008-02-01               4.9      -81.0       NaN
# 2008-03-01               5.1      -55.0       NaN
# 2008-04-01               5.0     -229.0  14805.61
# 2008-05-01               5.4     -184.0       NaN
# 2008-06-01               5.6     -154.0       NaN
# 2008-07-01               5.8     -213.0  14835.19
# 2008-08-01               6.1     -277.0       NaN
# 2008-09-01               6.1     -443.0       NaN
# 2008-10-01               6.5     -475.0  14559.54
# 2008-11-01               6.8     -759.0       NaN
# 2008-12-01               7.3     -707.0       NaN

# %%
# But now we can use dates.  Note also that we're using a string rather
# that a datetime object
df2.loc['2008-02-01']
# Out:
# UnemploymentRate     4.9
# JobsAdded          -81.0
# GDP                  NaN
# Name: 2008-02-01 00:00:00, dtype: float64

# %%
# what about a different date format?
df2.loc['02/01/08']
# Out:
# UnemploymentRate     4.9
# JobsAdded          -81.0
# GDP                  NaN
# Name: 2008-02-01 00:00:00, dtype: float64

# %%
# Now we can do a direct date range.
df2.loc['2012-01-01':'2012-12-01']
# Out:
#             UnemploymentRate  JobsAdded       GDP
# Month
# 2012-01-01               8.3      348.0  16019.76
# 2012-02-01               8.3      233.0       NaN
# 2012-03-01               8.2      264.0       NaN
# 2012-04-01               8.2       72.0  16152.26
# 2012-05-01               8.2      117.0       NaN
# 2012-06-01               8.2       68.0       NaN
# 2012-07-01               8.2      156.0  16257.15
# 2012-08-01               8.1      173.0       NaN
# 2012-09-01               7.8      194.0       NaN
# 2012-10-01               7.8      153.0  16358.86
# 2012-11-01               7.7      130.0       NaN
# 2012-12-01               7.9      243.0       NaN

# %%
df2.JobsAdded.loc['2012-01-01':'2012-12-01']
# Out:
# Month
# 2012-01-01    348.0
# 2012-02-01    233.0
# 2012-03-01    264.0
# 2012-04-01     72.0
# 2012-05-01    117.0
# 2012-06-01     68.0
# 2012-07-01    156.0
# 2012-08-01    173.0
# 2012-09-01    194.0
# 2012-10-01    153.0
# 2012-11-01    130.0
# 2012-12-01    243.0
# Name: JobsAdded, dtype: float64

# %% [markdown]
# ## Dealing with Missing Values - None and NaN Values

# %%
# what about null values?
df2.isnull().head(10)
# GDP is reported quarterly rather than monthly
# Note that the .head(10) is because I only want to see the first 10 rows.
# Out:
#             UnemploymentRate  JobsAdded    GDP
# Month
# 2008-01-01             False      False  False
# 2008-02-01             False      False   True
# 2008-03-01             False      False   True
# 2008-04-01             False      False  False
# 2008-05-01             False      False   True
# 2008-06-01             False      False   True
# 2008-07-01             False      False  False
# 2008-08-01             False      False   True
# 2008-09-01             False      False   True
# 2008-10-01             False      False  False

# %%
# NumPy functions do not handle NA and NaN value "well."
x = np.array(df2.GDP)
np.mean(x)
# Why the quotes on "well"?
# Out:
# nan

# %%
# Remove the NA values.  Note that the entire
# records (rows) are removed, not just the specific values.
df2.dropna()
# Out:
#             UnemploymentRate  JobsAdded       GDP
# Month
# 2008-01-01               5.0        8.0  14651.04
# 2008-04-01               5.0     -229.0  14805.61
# 2008-07-01               5.8     -213.0  14835.19
# 2008-10-01               6.5     -475.0  14559.54
# 2009-01-01               7.8     -787.0  14394.55
# 2009-04-01               9.0     -704.0  14352.85
# 2009-07-01               9.5     -342.0  14420.31
# 2009-10-01              10.0     -209.0  14628.02
# 2010-01-01               9.8       18.0  14721.35
# 2010-04-01               9.9      221.0  14926.10
# 2010-07-01               9.4      -78.0  15079.92
# 2010-10-01               9.4      267.0  15240.84
# 2011-01-01               9.1       44.0  15285.83
# 2011-04-01               9.1      323.0  15496.19
# 2011-07-01               9.0       72.0  15591.85
# 2011-10-01               8.8      209.0  15796.46
# 2012-01-01               8.3      348.0  16019.76
# 2012-04-01               8.2       72.0  16152.26
# 2012-07-01               8.2      156.0  16257.15
# 2012-10-01               7.8      153.0  16358.86
# 2013-01-01               8.0      207.0  16569.59
# 2013-04-01               7.6      179.0  16637.93
# 2013-07-01               7.3      111.0  16848.75
# 2013-10-01               7.2      210.0  17083.14
# 2014-01-01               6.6      174.0  17102.93
# 2014-04-01               6.3      311.0  17425.77
# 2014-07-01               6.2      196.0  17719.84
# 2014-10-01               5.7      255.0  17838.45
# 2015-01-01               5.7      211.0  17970.42
# 2015-04-01               5.4      282.0  18221.30
# 2015-07-01               5.2      256.0  18331.09
# 2015-10-01               5.0      351.0  18354.37
# 2016-01-01               4.9      103.0  18409.13
# 2016-04-01               5.0      174.0  18640.73
# 2016-07-01               4.9      325.0  18799.65
# 2016-10-01               4.9      140.0  18979.25
# 2017-01-01               4.8      259.0  19162.55
# 2017-04-01               4.4      175.0  19359.12
# 2017-07-01               4.3      190.0  19588.07
# 2017-10-01               4.1      271.0  19831.83
# 2018-01-01               4.1      176.0  20041.05
# 2018-04-01               3.9      175.0  20411.87
# 2018-07-01               3.9      147.0  20621.09

# %%
# Now we can use NumPy on the "good" values
x = np.array(df2.dropna()['GDP'])
np.mean(x)
# Why the quotes on "good"?
# Out:
# 16919.106976744188

# %%
# Or we can just use Pandas on the Series with the NA and NaN values
df2.GDP.mean()
# Out:
# 16919.106976744188

# %%
# And we can use the Pandas functions across the DataFrame
df2.mean()
# Out:
# UnemploymentRate        6.784375
# JobsAdded              84.906250
# GDP                 16919.106977
# dtype: float64

# %%
# What about non-numeric columns?  Recall that df1 has a Date (object) column.
df1.mean()
# Out:
# UnemploymentRate        6.784375
# JobsAdded              84.906250
# GDP                 16919.106977
# dtype: float64

# %%
# We can tell Pandas to apply the function to non-numeric columns (not
# sure why we'd want to do this, but we can).
df1.mean(numeric_only=False)
# See https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html for details.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1294             try:
# -> 1295                 x = x.astype(np.complex128)
#    1296             except (TypeError, ValueError):
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     541     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 542     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     543
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1296             except (TypeError, ValueError):
# -> 1297                 x = x.astype(np.float64)
#    1298             else:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-26c6c0b583b4> in <module>
#       1 # We can tell Pandas to apply the function to non-numeric columns (not
#       2 # sure why we'd want to do this, but we can).
# ----> 3 df1.mean(numeric_only=False)
#       4 # See https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html for details.
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11212         if level is not None:
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11214         return self._reduce(
#   11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7900             # After possibly _get_data and transposing, we are now in the
#    7901             #  simple case where we can use BlockManager._reduce
# -> 7902             res = df._data.reduce(blk_func)
#    7903             assert isinstance(res, dict)
#    7904             if len(res):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reduce(self, func, *args, **kwargs)
#     349         res = {}
#     350         for blk in self.blocks:
# --> 351             bres = func(blk.values, *args, **kwargs)
#     352
#     353             if np.ndim(bres) == 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in blk_func(values)
#    7896                     return values._reduce(name, skipna=skipna, **kwds)
#    7897                 else:
# -> 7898                     return op(values, axis=1, skipna=skipna, **kwds)
#    7899
#    7900             # After possibly _get_data and transposing, we are now in the
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74                 # object arrays that contain strings
#      75                 if is_object_dtype(args[0]):
# ---> 76                     raise TypeError(e)
#      77                 raise
#      78
#
# TypeError: could not convert string to float: '...'

# %% [markdown]
# ## Example Use-case With Pandas and Concatenation
# See the slide set for details of the problem.

# %%
# start with df2
df2 = pd.read_csv(filepath + '10_us_economic_data.csv', parse_dates = ['Month'], index_col=0)

# %%
# Extract the gdp data and drop the nan values
g = df2.GDP.dropna()
g.head(6)
# Out:
# Month
# 2008-01-01    14651.04
# 2008-04-01    14805.61
# 2008-07-01    14835.19
# 2008-10-01    14559.54
# 2009-01-01    14394.55
# 2009-04-01    14352.85
# Name: GDP, dtype: float64

# %%
# Create a series using the 2008 data (first 4 rows)
y1 = pd.Series(data = g.iloc[0:4].values, index=['Q1', 'Q2', 'Q3', 'Q4'], name="2008")
y1
# Out:
# Q1    14651.04
# Q2    14805.61
# Q3    14835.19
# Q4    14559.54
# Name: 2008, dtype: float64

# %%
# Replicate for year 2
y2 = pd.Series(data = g.iloc[4:8].values, index=['Q1', 'Q2', 'Q3', 'Q4'], name="2009")
y2
# Out:
# Q1    14394.55
# Q2    14352.85
# Q3    14420.31
# Q4    14628.02
# Name: 2009, dtype: float64

# %%
# Concatenate them together
gdp = pd.concat([y1, y2], axis=1)
show(gdp,1)
# Out:
#    Type: <class 'pandas.core.frame.DataFrame'>
#   Index: Index(['Q1', 'Q2', 'Q3', 'Q4'], dtype='object')
#   Shape: (4, 2)
# Columns: Index(['2008', '2009'], dtype='object')
#     2008 (float64)
#     2009 (float64)
#         2008      2009
# Q1  14651.04  14394.55
# Q2  14805.61  14352.85
# Q3  14835.19  14420.31
# Q4  14559.54  14628.02

# %%
# Now just replicate for years 3, 4,and 5 .... or create a small loop that automates the process.
